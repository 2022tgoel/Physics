# %% [markdown]
# # The [[5, 1, 3]] Code
# Notes and implementation of the ideas found in: https://www2.physics.ox.ac.uk/sites/default/files/ErrorCorrectionSteane06.pdf \
# https://www.scottaaronson.com/qclec.pdf - lecture 28
#
# some dude's master thesis:
# https://odr.chalmers.se/bitstream/20.500.12380/302690/1/Master_Thesis_Holmin_Andersson.pdf
# https://github.com/Serock3/Master_thesis_QEC_simulation

# %% [markdown]
# page 11:
# $X \otimes I \otimes Z \otimes Y \otimes X = X_{10011} Z_{00110}$
#
# $$$
# \begin{matrix}
#     X_{10011} & Z_{00110} & X_{10011} Z_{00110}\\
#     X & I & X\\
#     I & I & I\\
#     I & Z & Z\\
#     X & Z & Y\\
#     X & I & X\\
# \end{matrix}
# $$$

# %%
from qiskit.quantum_info import Operator

X = Operator([[0, 1], [1, 0]])
I = Operator([[1, 0], [0, 1]])
Z = Operator([[1, 0], [0, -1]])

# %%
out = X^I^Z^X.compose(Z)^X

# %%
out
# Out:
# Operator([[ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             1.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -1.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -1.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  1.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             1.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [-1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -1.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,
#             0.+0.j, -1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#            -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,
#            -1.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j],
#           [-0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j,
#            -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#             0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j]],
#          input_dims=(2, 2, 2, 2, 2), output_dims=(2, 2, 2, 2, 2))

# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
from QECcircuit import get_full_stabilizer_circuit

circuit = get_full_stabilizer_circuit(recovery=True)

# %%
circuit.draw()
# Out:
#                     ┌───┐┌───┐            ┌───┐          ░  ░  ░  ░ ┌───┐   »
#       code_qubit_0: ┤ Z ├┤ H ├─■──■──■──■─┤ H ├─■─────■──░──░──░──░─┤ H ├─■─»
#                     ├───┤└───┘ │  │  │  │ └───┘ │     │  ░  ░  ░  ░ └───┘ │ »
#       code_qubit_1: ┤ H ├──────■──┼──┼──┼───────■──■──┼──░──░──░──░───────┼─»
#                     ├───┤         │  │  │          │  │  ░  ░  ░  ░       │ »
#       code_qubit_2: ┤ H ├─────────■──┼──┼───■──────■──┼──░──░──░──░───────┼─»
#                     ├───┤            │  │   │         │  ░  ░  ░  ░ ┌───┐ │ »
#       code_qubit_3: ┤ H ├────────────■──┼───■───■─────┼──░──░──░──░─┤ H ├─┼─»
#                     ├───┤               │       │     │  ░  ░  ░  ░ └───┘ │ »
#       code_qubit_4: ┤ H ├───────────────■───────■─────■──░──░──░──░───────┼─»
#                     └───┘                                ░  ░  ░  ░       │ »
#    ancilla_qubit_0: ────────────────────────────────────────░─────░───────┼─»
#                                                             ░     ░ ┌───┐ │ »
#    ancilla_qubit_1: ────────────────────────────────────────░─────░─┤ H ├─■─»
#                                                             ░     ░ └───┘   »
# syndrome_cycle_0: 4/════════════════════════════════════════════════════════»
#                                                                             »
#          readout: 5/════════════════════════════════════════════════════════»
#                                                                             »
# «                    ┌───┐                    ░                            »
# «      code_qubit_0: ┤ H ├────────────────────░────────────────────────────»
# «                    └───┘                    ░ ┌───┐   ┌───┐              »
# «      code_qubit_1: ──■──────────────────────░─┤ H ├─■─┤ H ├──────────────»
# «                      │                      ░ └───┘ │ └───┘              »
# «      code_qubit_2: ──┼───■──────────────────░───────┼───■────────────────»
# «                      │   │    ┌───┐         ░       │   │                »
# «      code_qubit_3: ──┼───┼──■─┤ H ├─────────░───────┼───┼───■────────────»
# «                      │   │  │ └───┘         ░ ┌───┐ │   │   │    ┌───┐   »
# «      code_qubit_4: ──┼───┼──┼───────────────░─┤ H ├─┼───┼───┼──■─┤ H ├───»
# «                      │   │  │               ░ └───┘ │   │   │  │ └───┘   »
# «   ancilla_qubit_0: ──┼───┼──┼───────────────░───────┼───┼───┼──┼─────────»
# «                      │   │  │ ┌───┐┌─┐      ░ ┌───┐ │   │   │  │ ┌───┐┌─┐»
# «   ancilla_qubit_1: ──■───■──■─┤ H ├┤M├─|0>──░─┤ H ├─■───■───■──■─┤ H ├┤M├»
# «                               └───┘└╥┘      ░ └───┘              └───┘└╥┘»
# «syndrome_cycle_0: 4/═════════════════╩══════════════════════════════════╩═»
# «                                     0                                  1 »
# «         readout: 5/══════════════════════════════════════════════════════»
# «                                                                          »
# «                          ░ ┌───┐   ┌───┐                      ░            »
# «      code_qubit_0: ──────░─┤ H ├─■─┤ H ├──────────────────────░───────■────»
# «                          ░ └───┘ │ └───┘                      ░ ┌───┐ │    »
# «      code_qubit_1: ──────░───────┼────────────────────────────░─┤ H ├─┼──■─»
# «                          ░ ┌───┐ │      ┌───┐                 ░ └───┘ │  │ »
# «      code_qubit_2: ──────░─┤ H ├─┼───■──┤ H ├─────────────────░───────┼──┼─»
# «                          ░ └───┘ │   │  └───┘                 ░ ┌───┐ │  │ »
# «      code_qubit_3: ──────░───────┼───┼────■───────────────────░─┤ H ├─┼──┼─»
# «                          ░       │   │    │                   ░ └───┘ │  │ »
# «      code_qubit_4: ──────░───────┼───┼────┼───■───────────────░───────┼──┼─»
# «                          ░       │   │    │   │               ░       │  │ »
# «   ancilla_qubit_0: ──────░───────┼───┼────┼───┼───────────────░───────┼──┼─»
# «                          ░ ┌───┐ │   │    │   │ ┌───┐┌─┐      ░ ┌───┐ │  │ »
# «   ancilla_qubit_1: ─|0>──░─┤ H ├─■───■────■───■─┤ H ├┤M├─|0>──░─┤ H ├─■──■─»
# «                          ░ └───┘                └───┘└╥┘      ░ └───┘      »
# «syndrome_cycle_0: 4/═══════════════════════════════════╩════════════════════»
# «                                                       2                    »
# «         readout: 5/════════════════════════════════════════════════════════»
# «                                                                            »
# «                                            ░                             »
# «      code_qubit_0: ────────────────────────░─────────────────────────────»
# «                    ┌───┐                   ░  ┌───┐                      »
# «      code_qubit_1: ┤ H ├───────────────────░──┤ X ├──────────────────────»
# «                    └───┘                   ░  └─╥─┘         ┌───┐  ┌───┐ »
# «      code_qubit_2: ────────────────────────░────╫───────────┤ X ├──┤ Z ├─»
# «                         ┌───┐              ░    ║           └─╥─┘  └─╥─┘ »
# «      code_qubit_3: ──■──┤ H ├──────────────░────╫─────────────╫──────╫───»
# «                      │  └───┘              ░    ║    ┌───┐    ║      ║   »
# «      code_qubit_4: ──┼────■────────────────░────╫────┤ Z ├────╫──────╫───»
# «                      │    │                ░    ║    └─╥─┘    ║      ║   »
# «   ancilla_qubit_0: ──┼────┼────────────────░────╫──────╫──────╫──────╫───»
# «                      │    │  ┌───┐┌─┐      ░    ║      ║      ║      ║   »
# «   ancilla_qubit_1: ──■────■──┤ H ├┤M├─|0>──░────╫──────╫──────╫──────╫───»
# «                              └───┘└╥┘      ░ ┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐»
# «syndrome_cycle_0: 4/════════════════╩═════════╡ 0x1 ╞╡ 0x2 ╞╡ 0x3 ╞╡ 0x4 ╞»
# «                                    3         └─────┘└─────┘└─────┘└─────┘»
# «         readout: 5/══════════════════════════════════════════════════════»
# «                                                                          »
# «                     ┌───┐                       ┌───┐                      »
# «      code_qubit_0: ─┤ Z ├───────────────────────┤ X ├──────────────────────»
# «                     └─╥─┘                       └─╥─┘         ┌───┐  ┌───┐ »
# «      code_qubit_1: ───╫───────────────────────────╫───────────┤ Z ├──┤ X ├─»
# «                       ║           ┌───┐  ┌───┐    ║           └─╥─┘  └─╥─┘ »
# «      code_qubit_2: ───╫───────────┤ X ├──┤ Z ├────╫─────────────╫──────╫───»
# «                       ║    ┌───┐  └─╥─┘  └─╥─┘    ║    ┌───┐    ║      ║   »
# «      code_qubit_3: ───╫────┤ X ├────╫──────╫──────╫────┤ Z ├────╫──────╫───»
# «                       ║    └─╥─┘    ║      ║      ║    └─╥─┘    ║      ║   »
# «      code_qubit_4: ───╫──────╫──────╫──────╫──────╫──────╫──────╫──────╫───»
# «                       ║      ║      ║      ║      ║      ║      ║      ║   »
# «   ancilla_qubit_0: ───╫──────╫──────╫──────╫──────╫──────╫──────╫──────╫───»
# «                       ║      ║      ║      ║      ║      ║      ║      ║   »
# «   ancilla_qubit_1: ───╫──────╫──────╫──────╫──────╫──────╫──────╫──────╫───»
# «                    ┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐»
# «syndrome_cycle_0: 4/╡ 0x5 ╞╡ 0x6 ╞╡ 0x7 ╞╡ 0x7 ╞╡ 0x8 ╞╡ 0x9 ╞╡ 0xa ╞╡ 0xb ╞»
# «                    └─────┘└─────┘└─────┘└─────┘└─────┘└─────┘└─────┘└─────┘»
# «         readout: 5/════════════════════════════════════════════════════════»
# «                                                                            »
# «                                   ┌───┐  ┌───┐                             »
# «      code_qubit_0: ───────────────┤ X ├──┤ Z ├─────────────────────────────»
# «                     ┌───┐         └─╥─┘  └─╥─┘                             »
# «      code_qubit_1: ─┤ Z ├───────────╫──────╫───────────────────────────────»
# «                     └─╥─┘           ║      ║                               »
# «      code_qubit_2: ───╫─────────────╫──────╫───────────────────────────────»
# «                       ║             ║      ║                  ┌───┐  ┌───┐ »
# «      code_qubit_3: ───╫─────────────╫──────╫──────────────────┤ X ├──┤ Z ├─»
# «                       ║    ┌───┐    ║      ║    ┌───┐  ┌───┐  └─╥─┘  └─╥─┘ »
# «      code_qubit_4: ───╫────┤ X ├────╫──────╫────┤ X ├──┤ Z ├────╫──────╫───»
# «                       ║    └─╥─┘    ║      ║    └─╥─┘  └─╥─┘    ║      ║   »
# «   ancilla_qubit_0: ───╫──────╫──────╫──────╫──────╫──────╫──────╫──────╫───»
# «                       ║      ║      ║      ║      ║      ║      ║      ║   »
# «   ancilla_qubit_1: ───╫──────╫──────╫──────╫──────╫──────╫──────╫──────╫───»
# «                    ┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐┌──╨──┐»
# «syndrome_cycle_0: 4/╡ 0xb ╞╡ 0xc ╞╡ 0xd ╞╡ 0xd ╞╡ 0xe ╞╡ 0xe ╞╡ 0xf ╞╡ 0xf ╞»
# «                    └─────┘└─────┘└─────┘└─────┘└─────┘└─────┘└─────┘└─────┘»
# «         readout: 5/════════════════════════════════════════════════════════»
# «                                                                            »
# «                     ░  ░  ░ ┌───────┐┌─┐
# «      code_qubit_0: ─░──░──░─┤ delay ├┤M├────────────
# «                     ░  ░  ░ ├───────┤└╥┘┌─┐
# «      code_qubit_1: ─░──░──░─┤ delay ├─╫─┤M├─────────
# «                     ░  ░  ░ ├───────┤ ║ └╥┘┌─┐
# «      code_qubit_2: ─░──░──░─┤ delay ├─╫──╫─┤M├──────
# «                     ░  ░  ░ ├───────┤ ║  ║ └╥┘┌─┐
# «      code_qubit_3: ─░──░──░─┤ delay ├─╫──╫──╫─┤M├───
# «                     ░  ░  ░ ├───────┤ ║  ║  ║ └╥┘┌─┐
# «      code_qubit_4: ─░──░──░─┤ delay ├─╫──╫──╫──╫─┤M├
# «                     ░  ░  ░ ├───────┤ ║  ║  ║  ║ └╥┘
# «   ancilla_qubit_0: ─░─────░─┤ delay ├─╫──╫──╫──╫──╫─
# «                     ░     ░ ├───────┤ ║  ║  ║  ║  ║
# «   ancilla_qubit_1: ─░─────░─┤ delay ├─╫──╫──╫──╫──╫─
# «                     ░     ░ └───────┘ ║  ║  ║  ║  ║
# «syndrome_cycle_0: 4/═══════════════════╬══╬══╬══╬══╬═
# «                                       ║  ║  ║  ║  ║
# «         readout: 5/═══════════════════╩══╩══╩══╩══╩═
# «                                       0  1  2  3  4

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c782e670-8153-4fc7-a9a3-0ae2dddfa952' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
